# %%
# %load_ext autoreload

# %autoreload 2

# %matplotlib inline

# %%
from kerasUtils import *

faceSamples, _ = splitDataSet("/media/al/0fd62943-862a-40b9-a4db-fe92a880b732/balancedCleandDataSet", 0.0, 42) # 1 to 1 Dataset
print('Loaded {} samples '.format(len(faceSamples)))
lipSamples, _ = splitDataSet("/media/al/0fd62943-862a-40b9-a4db-fe92a880b732/lipImageDataset", 0.0, 42) # 1 to 1 Dataset
print('Loaded {} samples '.format(len(lipSamples)))

#train, test = splitDataSet("/media/al/bcaed2d1-c378-44e2-a581-fae772b468db/data/lipFeaturesDataset", 0.15, 42) # 2 to 1 Dataset
faceFeatureSamples, _ = splitDataSet("/media/al/0fd62943-862a-40b9-a4db-fe92a880b732/faceFeaturesDataset", 0.0, 42) # 1 to 1 Dataset
print('Loaded {} samples '.format(len(faceFeatureSamples)))
lipFeatureSamples, _ = splitDataSet("/media/al/0fd62943-862a-40b9-a4db-fe92a880b732/lipFeaturesDataset", 0.0, 42) # 1 to 1 Dataset
print('Loaded {} samples '.format(len(lipFeatureSamples)))
# Out:
# Using TensorFlow backend.
# The following GPU devices are available: /device:GPU:0
# Loaded 22144 positive samples and 22145 negative samples
# Loaded 44289 samples
# Loaded 22144 positive samples and 22145 negative samples
# Loaded 44289 samples
# Loaded 22144 positive samples and 22145 negative samples
# Loaded 44289 samples
# Loaded 22144 positive samples and 22145 negative samples
# Loaded 44289 samples

# %%
from sample import *
import os
from pathlib import Path, PurePath
visFolder = '../dataVisualizations'
if not os.path.exists(visFolder):
        os.makedirs(visFolder)

# sample = FeaturedSample()
# sample.load(faceFeatureSamples[0])
# sample.visualize(saveTo="FaceFeaturesSample.gif") 


smaplesNegPosEach = 10

samples = ['../wrongLabels/FaceImages/negativeSamples/6178.pickle', '../wrongLabels/FaceImages/positiveSamples/31366.pickle']


# pathes = []
# pathes.extend(faceSamples[-smaplesNegPosEach:])
# pathes.extend(faceSamples[:smaplesNegPosEach])
for samplePath in samples:
    sample = FeaturedSample()
    sample.load(samplePath)
    path = Path(samplePath)
    sampleNum = path.stem
    sample.visualize(saveTo=os.path.join(visFolder, "{}_{}_{}.gif".format(sampleNum, sample.featureType, sample.getLabel())))
    
# pathes = []
# pathes.extend(lipSamples[-smaplesNegPosEach:])
# pathes.extend(lipSamples[:smaplesNegPosEach]) 
# for samplePath in pathes:
#     sample = FeaturedSample()
#     sample.load(samplePath)
#     path = Path(samplePath)
#     sampleNum = path.stem
#     sample.visualize(saveTo=os.path.join(visFolder, "{}_{}_{}.gif".format(sampleNum, sample.featureType, sample.getLabel())))
    
# pathes = []
# pathes.extend(faceFeatureSamples[-smaplesNegPosEach:])
# pathes.extend(faceFeatureSamples[:smaplesNegPosEach])
# for samplePath in pathes:
#     sample = FeaturedSample()
#     sample.load(samplePath)
#     path = Path(samplePath)
#     sampleNum = path.stem
#     sample.visualize(saveTo=os.path.join(visFolder, "{}_{}_{}.gif".format(sampleNum, sample.featureType, sample.getLabel())))
    
# pathes = []
# pathes.extend(lipFeatureSamples[-smaplesNegPosEach:])
# pathes.extend(lipFeatureSamples[:smaplesNegPosEach]) 
# for samplePath in pathes:
#     sample = FeaturedSample()
#     sample.load(samplePath)
#     path = Path(samplePath)
#     sampleNum = path.stem
#     sample.visualize(saveTo=os.path.join(visFolder, "{}_{}_{}.gif".format(sampleNum, sample.featureType, sample.getLabel())))
# Out:
# shape: (38, 200, 200, 3)
# shape: (38, 200, 200, 3)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.animation import PillowWriter

fig = plt.figure()

def f(x, y):
    return np.sin(x) + np.cos(y)

x = np.linspace(0, 2 * np.pi, 120)
y = np.linspace(0, 2 * np.pi, 100).reshape(-1, 1)
# ims is a list of lists, each row is a list of artists to draw in the
# current frame; here we are just animating one artist, the image, in
# each frame
ims = []
for i in range(20):
    x += np.pi / 15.
    y += np.pi / 20.
    im = plt.imshow(f(x, y))
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=500)

ani.save("demo2.gif", writer='imagemagick')

plt.show()
