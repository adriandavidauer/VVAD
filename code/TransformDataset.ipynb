# %%
# %load_ext autoreload

# %autoreload 2

# %matplotlib inline

# %%
from dataSet import *
from kerasUtils import *
from random import shuffle

#train, test = splitDataSet("/home/alubitz/Downloads/balancedCleanedDataSet_5GB", 0.15, 42)

#train, test = splitDataSet("/media/al/bcaed2d1-c378-44e2-a581-fae772b468db/data/balancedCleanedDataSet_5GB", 0.15, 42) #small test set 1 to 1

train, test = splitDataSet("/media/al/0fd62943-862a-40b9-a4db-fe92a880b732/balancedCleandDataSet", 0.0, 42) # 1 to 1 Dataset
print('Loaded {} training samples and {} validation samples'.format(len(train), len(test)))

trainParams = [(x, '/media/al/bcaed2d1-c378-44e2-a581-fae772b468db/models/shape_predictor_68_face_landmarks.dat', (100, 50, 3)) for x in train]
shuffle(trainParams)
# print (trainParams[0])
# print (trainParams[99])
# print (trainParams[9999])
# Out:
# Using TensorFlow backend.
# The following GPU devices are available: /device:GPU:0
# Loaded 22244 positive samples and 22245 negative samples
# Loaded 44489 training samples and 0 validation samples

# %%
from multiprocessing import Pool
p = Pool(multiprocessing.cpu_count())
p.starmap(transformToFeatures, trainParams)


# for i ,_ in enumerate(p.starmap(transformToFeatures, trainParams)):
#     pr = (i / len(train))*100
#     print ('\r', 'Transforming dataset: {:.2f}%\r'.format(pr),end='')


# for i, sample in enumerate(train):
#     pr = (i / len(train))*100
#     transformToFeatures(sample, '/media/al/bcaed2d1-c378-44e2-a581-fae772b468db/models/shape_predictor_68_face_landmarks.dat', (100, 50, 3))
#     print ('\r', 'Transforming dataset: {:.2f}%\r'.format(pr),end='')
# print ('\r', 'Transforming dataset: {:.2f}%\r'.format(100.0),end='')
# print()
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...
